# %% [markdown]
# **HyperParam tuning using gridSearch**

# %%
#9th main
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.ensemble import GradientBoostingRegressor

# %%
concrete = pd.read_csv("./datasets/concrete_data.csv")

concrete.head()
# Out:
#    cement   slag  flyash  water  superplasticizer  coarseaggregate  \
# 0   540.0    0.0     0.0  162.0               2.5           1040.0
# 1   540.0    0.0     0.0  162.0               2.5           1055.0
# 2   332.5  142.5     0.0  228.0               0.0            932.0
# 3   332.5  142.5     0.0  228.0               0.0            932.0
# 4   198.6  132.4     0.0  192.0               0.0            978.4
#
#    fineaggregate  age  csMPa
# 0          676.0   28  79.99
# 1          676.0   28  61.89
# 2          594.0  270  40.27
# 3          594.0  365  41.05
# 4          825.5  360  44.30

# %%
X = concrete.drop("csMPa", axis = 1)
Y = concrete.csMPa

# %%
X = X.drop(["flyash", "coarseaggregate", "fineaggregate"], axis = 1)  # done to reduce dim, and help increase speed

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2)

# %%
# baseline model, i.e new model acc mustn't be lower than this
baseline = GradientBoostingRegressor(max_depth=3, n_estimators=50)
baseline.fit(x_train, y_train)
# Out:
# GradientBoostingRegressor(n_estimators=50)

# %%
from sklearn.metrics import r2_score

y_pred = baseline.predict(x_test)

r2_score(y_test, y_pred)
# Out:
# 0.8839824620612463

# %%
# get importance of feature to the model
important_features = pd.Series(baseline.feature_importances_, index = X.columns).sort_values(ascending = False)

important_features
# Out:
# age                 0.373695
# cement              0.336937
# water               0.106723
# slag                0.092027
# superplasticizer    0.090618
# dtype: float64

# %%
# gridSearch
gbr = GradientBoostingRegressor(max_depth=3)

parameters = {"n_estimators": [1, 5, 10, 50, 100, 200, 300, 400, 500]}

gridsearch_reg = GridSearchCV(gbr, param_grid=parameters, cv = 3, n_jobs=-1)

gridsearch_reg.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=3, estimator=GradientBoostingRegressor(), n_jobs=-1,
#              param_grid={'n_estimators': [1, 5, 10, 50, 100, 200, 300, 400,
#                                           500]})

# %%
gridsearch_reg.best_params_
# Out:
# {'n_estimators': 500}

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2)

# %%
gbr_best = GradientBoostingRegressor(max_depth=3, n_estimators=gridsearch_reg.best_params_["n_estimators"])
gbr_best.fit(x_train, y_train)
# Out:
# GradientBoostingRegressor(n_estimators=500)

# %%
y_pred = gbr_best.predict(x_test)

r2_score(y_test, y_pred)
# Out:
# 0.908121532281322

# %% [markdown]
# ***
# **HyperParam tuning using EarlyStopping**

# %%
"""
warmstart = True, means reuse solutions of previous call to predictor to fit and add
more estimators of ensemble
"""
gbr = GradientBoostingRegressor(max_depth = 3, warm_start = True)

# %%
# early stopping code
min_val_error = float("inf")
error_increasing = 0

for n_estimators in range(1, 1000):
    gbr.n_estimators = n_estimators
    gbr.fit(x_train, y_train)
    
    y_pred = gbr.predict(x_test)
    val_error = mean_squared_error(y_test, y_pred)
    
    print("No. of estimators: ", gbr.n_estimators)
    print("Error: ", val_error)
    
    if val_error < min_val_error:  # error reducing
        min_val_error = val_error  # updates min error value
        error_increasing = 0
    else:
        error_increasing += 1
        if error_increasing == 10:   # error keeps increasing for 6 times i.e overfitting
            break
# Out:
# No. of estimators:  1
# Error:  248.25361502502042
# No. of estimators:  2
# Error:  220.49859594097288
# No. of estimators:  3
# Error:  200.19143337231247
# No. of estimators:  4
# Error:  181.14100447646504
# No. of estimators:  5
# Error:  166.56320389126617
# No. of estimators:  6
# Error:  155.31045711839968
# No. of estimators:  7
# Error:  144.5611978815204
# No. of estimators:  8
# Error:  133.27717145265842
# No. of estimators:  9
# Error:  125.56838158487218
# No. of estimators:  10
# Error:  117.90978813630247
# No. of estimators:  11
# Error:  109.67586287218188
# No. of estimators:  12
# Error:  104.82235188043342
# No. of estimators:  13
# Error:  98.63437768498775
# No. of estimators:  14
# Error:  92.46391267192352
# No. of estimators:  15
# Error:  86.86636980245237
# No. of estimators:  16
# Error:  82.87443680378821
# No. of estimators:  17
# Error:  80.3824670285934
# No. of estimators:  18
# Error:  76.65734080884852
# No. of estimators:  19
# Error:  74.331669450294
# No. of estimators:  20
# Error:  71.05805838420815
# No. of estimators:  21
# Error:  68.54326887682
# No. of estimators:  22
# Error:  66.33013761725395
# No. of estimators:  23
# Error:  64.13492308551338
# No. of estimators:  24
# Error:  62.35865210314689
# No. of estimators:  25
# Error:  61.12402370504257
# No. of estimators:  26
# Error:  59.6670238231304
# No. of estimators:  27
# Error:  58.4456604742286
# No. of estimators:  28
# Error:  57.183417088346225
# No. of estimators:  29
# Error:  55.840633820963454
# No. of estimators:  30
# Error:  54.832118715721165
# No. of estimators:  31
# Error:  53.34012771938572
# No. of estimators:  32
# Error:  52.27393540049293
# No. of estimators:  33
# Error:  51.61987811934573
# No. of estimators:  34
# Error:  50.925575873483474
# No. of estimators:  35
# Error:  50.498050737106155
# No. of estimators:  36
# Error:  49.81953837488986
# No. of estimators:  37
# Error:  49.20637614679934
# No. of estimators:  38
# Error:  48.467855602337806
# No. of estimators:  39
# Error:  47.85794452091821
# No. of estimators:  40
# Error:  47.380942498857316
# No. of estimators:  41
# Error:  46.86564615963366
# No. of estimators:  42
# Error:  46.42109067556054
# No. of estimators:  43
# Error:  45.559253384827315
# No. of estimators:  44
# Error:  44.989339393555994
# No. of estimators:  45
# Error:  44.66016304947152
# No. of estimators:  46
# Error:  44.48280300490846
# No. of estimators:  47
# Error:  44.09434293031099
# No. of estimators:  48
# Error:  43.85697316322695
# No. of estimators:  49
# Error:  43.45957120156578
# No. of estimators:  50
# Error:  43.18508567139476
# No. of estimators:  51
# Error:  42.8784933324334
# No. of estimators:  52
# Error:  42.458436257470325
# No. of estimators:  53
# Error:  42.07422791780858
# No. of estimators:  54
# Error:  41.86885782251767
# No. of estimators:  55
# Error:  41.6226984665922
# No. of estimators:  56
# Error:  41.42509889289391
# No. of estimators:  57
# Error:  41.24702825188552
# No. of estimators:  58
# Error:  41.06877476429353
# No. of estimators:  59
# Error:  40.85331077720087
# No. of estimators:  60
# Error:  40.641112761073586
# No. of estimators:  61
# Error:  40.40572080790174
# No. of estimators:  62
# Error:  39.956482184165765
# No. of estimators:  63
# Error:  39.64383051018501
# No. of estimators:  64
# Error:  39.64101187773186
# No. of estimators:  65
# Error:  39.32712554958157
# No. of estimators:  66
# Error:  39.21081773494023
# No. of estimators:  67
# Error:  38.84088142164125
# No. of estimators:  68
# Error:  38.64051464134862
# No. of estimators:  69
# Error:  38.49411679295057
# No. of estimators:  70
# Error:  38.42725423709861
# No. of estimators:  71
# Error:  38.23849270491574
# No. of estimators:  72
# Error:  38.220041251410656
# No. of estimators:  73
# Error:  37.82818115300489
# No. of estimators:  74
# Error:  37.6020937669873
# No. of estimators:  75
# Error:  37.56659094776679
# No. of estimators:  76
# Error:  37.49473695821005
# No. of estimators:  77
# Error:  37.332010244406305
# No. of estimators:  78
# Error:  37.16442055028987
# No. of estimators:  79
# Error:  36.84414256875381
# No. of estimators:  80
# Error:  36.782625553575535
# No. of estimators:  81
# Error:  36.71354938811381
# No. of estimators:  82
# Error:  36.60510024750438
# No. of estimators:  83
# Error:  36.34262034524004
# No. of estimators:  84
# Error:  36.335420382110094
# No. of estimators:  85
# Error:  36.082288840902265
# No. of estimators:  86
# Error:  35.95695280236145
# No. of estimators:  87
# Error:  35.928524887656614
# No. of estimators:  88
# Error:  35.91809333820166
# No. of estimators:  89
# Error:  35.734695996489556
# No. of estimators:  90
# Error:  35.7598188152748
# No. of estimators:  91
# Error:  35.678189839718826
# No. of estimators:  92
# Error:  35.61320875097713
# No. of estimators:  93
# Error:  35.38724873518101
# No. of estimators:  94
# Error:  35.24020658863196
# No. of estimators:  95
# Error:  34.7784555034405
# No. of estimators:  96
# Error:  34.69277753811871
# No. of estimators:  97
# Error:  34.63295210867573
# No. of estimators:  98
# Error:  34.50155898940176
# No. of estimators:  99
# Error:  34.358200284577435
# No. of estimators:  100
# Error:  34.29297817439885
# No. of estimators:  101
# Error:  34.24414178949574
# No. of estimators:  102
# Error:  34.186271781022846
# No. of estimators:  103
# Error:  34.20393426254163
# No. of estimators:  104
# Error:  34.1445813128227
# No. of estimators:  105
# Error:  34.10370874770212
# No. of estimators:  106
# Error:  34.03548503710383
# No. of estimators:  107
# Error:  33.95616461952734
# No. of estimators:  108
# Error:  33.87674414033748
# No. of estimators:  109
# Error:  33.89222218000276
# No. of estimators:  110
# Error:  33.76564167659083
# No. of estimators:  111
# Error:  33.75452925487204
# No. of estimators:  112
# Error:  33.593792124274394
# No. of estimators:  113
# Error:  33.391254705581744
# No. of estimators:  114
# Error:  33.349894218127886
# No. of estimators:  115
# Error:  33.323751394061325
# No. of estimators:  116
# Error:  33.36495305074247
# No. of estimators:  117
# Error:  33.29182185632292
# No. of estimators:  118
# Error:  33.316188610415196
# No. of estimators:  119
# Error:  33.21701086802367
# No. of estimators:  120
# Error:  33.032585502934744
# No. of estimators:  121
# Error:  32.987548631167336
# No. of estimators:  122
# Error:  32.94992994030887
# No. of estimators:  123
# Error:  32.96840217813388
# No. of estimators:  124
# Error:  32.837726734824074
# No. of estimators:  125
# Error:  32.54111017701806
# No. of estimators:  126
# Error:  32.568323342652846
# No. of estimators:  127
# Error:  32.51310948491455
# No. of estimators:  128
# Error:  32.46219275156758
# No. of estimators:  129
# Error:  32.306722942017345
# No. of estimators:  130
# Error:  32.26957844743385
# No. of estimators:  131
# Error:  32.311453931761285
# No. of estimators:  132
# Error:  32.298075238147156
# No. of estimators:  133
# Error:  32.19115779084949
# No. of estimators:  134
# Error:  32.06002121680701
# No. of estimators:  135
# Error:  31.986574251341032
# No. of estimators:  136
# Error:  31.98036352269574
# No. of estimators:  137
# Error:  31.889420943682108
# No. of estimators:  138
# Error:  31.804304636732066
# No. of estimators:  139
# Error:  31.799327915890547
# No. of estimators:  140
# Error:  31.780110281410458
# No. of estimators:  141
# Error:  31.783358895543
# No. of estimators:  142
# Error:  31.763256080996456
# No. of estimators:  143
# Error:  31.662467252094114
# No. of estimators:  144
# Error:  31.682852367202234
# No. of estimators:  145
# Error:  31.62014042343262
# No. of estimators:  146
# Error:  31.48314351200839
# No. of estimators:  147
# Error:  31.476745847709303
# No. of estimators:  148
# Error:  31.46762633153852
# No. of estimators:  149
# Error:  31.305605826816258
# No. of estimators:  150
# Error:  31.314611558510073
# No. of estimators:  151
# Error:  31.30073526191387
# No. of estimators:  152
# Error:  31.251187543673854
# No. of estimators:  153
# Error:  31.25396722968067
# No. of estimators:  154
# Error:  31.281591546548377
# No. of estimators:  155
# Error:  31.237664757479227
# No. of estimators:  156
# Error:  31.19011259447203
# No. of estimators:  157
# Error:  31.1216812296585
# No. of estimators:  158
# Error:  31.11460476034728
# No. of estimators:  159
# Error:  31.0727737885476
# No. of estimators:  160
# Error:  31.002917026127566
# No. of estimators:  161
# Error:  30.993057121703046
# No. of estimators:  162
# Error:  30.985401136904397
# No. of estimators:  163
# Error:  30.91533476787276
# No. of estimators:  164
# Error:  30.897618289239997
# No. of estimators:  165
# Error:  30.94085204880296
# No. of estimators:  166
# Error:  30.930889516669488
# No. of estimators:  167
# Error:  30.88749263578972
# No. of estimators:  168
# Error:  30.857783667599254
# No. of estimators:  169
# Error:  30.63209975309577
# No. of estimators:  170
# Error:  30.58355554184467
# No. of estimators:  171
# Error:  30.478396475319684
# No. of estimators:  172
# Error:  30.425202894844656
# No. of estimators:  173
# Error:  30.34078581422395
# No. of estimators:  174
# Error:  30.34506074224279
# No. of estimators:  175
# Error:  30.329776770260818
# No. of estimators:  176
# Error:  30.271271941613573
# No. of estimators:  177
# Error:  30.208293518507727
# No. of estimators:  178
# Error:  30.054467407813476
# No. of estimators:  179
# Error:  29.932213637723276
# No. of estimators:  180
# Error:  29.93903593357117
# No. of estimators:  181
# Error:  29.87194474691782
# No. of estimators:  182
# Error:  29.82552928468271
# No. of estimators:  183
# Error:  29.816552468459378
# No. of estimators:  184
# Error:  29.805422480418326
# No. of estimators:  185
# Error:  29.81620282673624
# No. of estimators:  186
# Error:  29.83285636293987
# No. of estimators:  187
# Error:  29.81244430059229
# No. of estimators:  188
# Error:  29.683889710333347
# No. of estimators:  189
# Error:  29.58325521969622
# No. of estimators:  190
# Error:  29.573031758149657
# No. of estimators:  191
# Error:  29.484318159505687
# No. of estimators:  192
# Error:  29.497799313424455
# No. of estimators:  193
# Error:  29.487178994566634
# No. of estimators:  194
# Error:  29.469330166465394
# No. of estimators:  195
# Error:  29.4710957298392
# No. of estimators:  196
# Error:  29.430070783243973
# No. of estimators:  197
# Error:  29.469749026808987
# No. of estimators:  198
# Error:  29.415782647587893
# No. of estimators:  199
# Error:  29.406924723861486
# No. of estimators:  200
# Error:  29.26362444921435
# No. of estimators:  201
# Error:  29.23283196652625
# No. of estimators:  202
# Error:  29.20873042494199
# No. of estimators:  203
# Error:  29.142138873712064
# No. of estimators:  204
# Error:  29.11835526125507
# No. of estimators:  205
# Error:  29.109190067388553
# No. of estimators:  206
# Error:  29.042949330248405
# No. of estimators:  207
# Error:  28.97402427587516
# No. of estimators:  208
# Error:  29.02965647698133
# No. of estimators:  209
# Error:  29.049941136761518
# No. of estimators:  210
# Error:  28.968743429656502
# No. of estimators:  211
# Error:  28.892131479401176
# No. of estimators:  212
# Error:  28.84299722767877
# No. of estimators:  213
# Error:  28.783405556597373
# No. of estimators:  214
# Error:  28.763089288693575
# No. of estimators:  215
# Error:  28.710684244620623
# No. of estimators:  216
# Error:  28.669907531441275
# No. of estimators:  217
# Error:  28.60195246560998
# No. of estimators:  218
# Error:  28.571291186433307
# No. of estimators:  219
# Error:  28.564597223521304
# No. of estimators:  220
# Error:  28.490842422839894
# No. of estimators:  221
# Error:  28.429480812933203
# No. of estimators:  222
# Error:  28.426706123584083
# No. of estimators:  223
# Error:  28.38440548854934
# No. of estimators:  224
# Error:  28.395089968990785
# No. of estimators:  225
# Error:  28.315817057268266
# No. of estimators:  226
# Error:  28.271389768843576
# No. of estimators:  227
# Error:  28.241146381411312
# No. of estimators:  228
# Error:  28.13969250524713
# No. of estimators:  229
# Error:  28.11725288198108
# No. of estimators:  230
# Error:  28.087777172770718
# No. of estimators:  231
# Error:  28.05342724134683
# No. of estimators:  232
# Error:  28.010832681490594
# No. of estimators:  233
# Error:  27.994020431152858
# No. of estimators:  234
# Error:  27.95131156229985
# No. of estimators:  235
# Error:  27.899254738677026
# No. of estimators:  236
# Error:  27.786167028703566
# No. of estimators:  237
# Error:  27.762963264112294
# No. of estimators:  238
# Error:  27.715205491619468
# No. of estimators:  239
# Error:  27.709256780974375
# No. of estimators:  240
# Error:  27.60248981309735
# No. of estimators:  241
# Error:  27.59623636191104
# No. of estimators:  242
# Error:  27.604925913388136
# No. of estimators:  243
# Error:  27.588937624860556
# No. of estimators:  244
# Error:  27.548568518411
# No. of estimators:  245
# Error:  27.549536966449335
# No. of estimators:  246
# Error:  27.548756814779956
# No. of estimators:  247
# Error:  27.528078850837048
# No. of estimators:  248
# Error:  27.488142912273652
# No. of estimators:  249
# Error:  27.420935701068462
# No. of estimators:  250
# Error:  27.347945266308272
# No. of estimators:  251
# Error:  27.329344383803697
# No. of estimators:  252
# Error:  27.309029887873507
# No. of estimators:  253
# Error:  27.270653570414638
# No. of estimators:  254
# Error:  27.25682895575406
# No. of estimators:  255
# Error:  27.242895172877855
# No. of estimators:  256
# Error:  27.20650247597141
# No. of estimators:  257
# Error:  27.20615922598835
# No. of estimators:  258
# Error:  27.19849082476126
# No. of estimators:  259
# Error:  27.17558701422906
# No. of estimators:  260
# Error:  27.165295479087924
# No. of estimators:  261
# Error:  27.133701918792944
# No. of estimators:  262
# Error:  27.11174550472795
# No. of estimators:  263
# Error:  27.108682132444944
# No. of estimators:  264
# Error:  27.09965129124886
# No. of estimators:  265
# Error:  27.096572415164097
# No. of estimators:  266
# Error:  27.028950034014937
# No. of estimators:  267
# Error:  26.93097246051802
# No. of estimators:  268
# Error:  26.917582989265462
# No. of estimators:  269
# Error:  26.848424488057603
# No. of estimators:  270
# Error:  26.763763595614495
# No. of estimators:  271
# Error:  26.71617979728546
# No. of estimators:  272
# Error:  26.722283198165023
# No. of estimators:  273
# Error:  26.673626091727364
# No. of estimators:  274
# Error:  26.650586452179684
# No. of estimators:  275
# Error:  26.624851945961417
# No. of estimators:  276
# Error:  26.62725968981571
# No. of estimators:  277
# Error:  26.578917921834794
# No. of estimators:  278
# Error:  26.576988205474244
# No. of estimators:  279
# Error:  26.563797431650528
# No. of estimators:  280
# Error:  26.490372018445818
# No. of estimators:  281
# Error:  26.439576956140574
# No. of estimators:  282
# Error:  26.434201768815605
# No. of estimators:  283
# Error:  26.387059947564364
# No. of estimators:  284
# Error:  26.372166076552453
# No. of estimators:  285
# Error:  26.317629717443594
# No. of estimators:  286
# Error:  26.31809163723638
# No. of estimators:  287
# Error:  26.319752000373978
# No. of estimators:  288
# Error:  26.289125877632756
# No. of estimators:  289
# Error:  26.278081858677087
# No. of estimators:  290
# Error:  26.245229152714856
# No. of estimators:  291
# Error:  26.2485787601467
# No. of estimators:  292
# Error:  26.270134292713294
# No. of estimators:  293
# Error:  26.24448999188885
# No. of estimators:  294
# Error:  26.296708454141392
# No. of estimators:  295
# Error:  26.28552355170105
# No. of estimators:  296
# Error:  26.212111148771253
# No. of estimators:  297
# Error:  26.172697798511287
# No. of estimators:  298
# Error:  26.156018238755056
# No. of estimators:  299
# Error:  26.15762833963472
# No. of estimators:  300
# Error:  26.113573622739107
# No. of estimators:  301
# Error:  26.10330318252511
# No. of estimators:  302
# Error:  26.077334250620808
# No. of estimators:  303
# Error:  26.03743932662296
# No. of estimators:  304
# Error:  26.094355060005945
# No. of estimators:  305
# Error:  26.085226603677075
# No. of estimators:  306
# Error:  26.071903289194015
# No. of estimators:  307
# Error:  26.028015279109834
# No. of estimators:  308
# Error:  26.015964640481798
# No. of estimators:  309
# Error:  26.05539718270549
# No. of estimators:  310
# Error:  26.063937049888047
# No. of estimators:  311
# Error:  26.047768636743587
# No. of estimators:  312
# Error:  26.101167805406124
# No. of estimators:  313
# Error:  26.07325113803346
# No. of estimators:  314
# Error:  26.040136190081153
# No. of estimators:  315
# Error:  26.02126700795489
# No. of estimators:  316
# Error:  25.99276255848095
# No. of estimators:  317
# Error:  25.967417944464437
# No. of estimators:  318
# Error:  25.949658642643087
# No. of estimators:  319
# Error:  25.909484711976997
# No. of estimators:  320
# Error:  25.915746030265105
# No. of estimators:  321
# Error:  25.908571686890976
# No. of estimators:  322
# Error:  25.88050290564229
# No. of estimators:  323
# Error:  25.767637351246528
# No. of estimators:  324
# Error:  25.765346934506418
# No. of estimators:  325
# Error:  25.774191140831373
# No. of estimators:  326
# Error:  25.77170855237031
# No. of estimators:  327
# Error:  25.79382294929809
# No. of estimators:  328
# Error:  25.79162766547404
# No. of estimators:  329
# Error:  25.776419191251186
# No. of estimators:  330
# Error:  25.664871148508354
# No. of estimators:  331
# Error:  25.669881285212757
# No. of estimators:  332
# Error:  25.659547813738886
# No. of estimators:  333
# Error:  25.65539297451043
# No. of estimators:  334
# Error:  25.566433893674148
# No. of estimators:  335
# Error:  25.549297897780875
# No. of estimators:  336
# Error:  25.523975420260356
# No. of estimators:  337
# Error:  25.52228179229149
# No. of estimators:  338
# Error:  25.511365004502434
# No. of estimators:  339
# Error:  25.509600564677896
# No. of estimators:  340
# Error:  25.534783557399102
# No. of estimators:  341
# Error:  25.525868561336786
# No. of estimators:  342
# Error:  25.46653837940202
# No. of estimators:  343
# Error:  25.441419347588436
# No. of estimators:  344
# Error:  25.417101145855572
# No. of estimators:  345
# Error:  25.410901616965372
# No. of estimators:  346
# Error:  25.408384497314604
# No. of estimators:  347
# Error:  25.396251322487462
# No. of estimators:  348
# Error:  25.383156309590934
# No. of estimators:  349
# Error:  25.36673707947353
# No. of estimators:  350
# Error:  25.364333255103023
# No. of estimators:  351
# Error:  25.358589294847334
# No. of estimators:  352
# Error:  25.366152251569872
# No. of estimators:  353
# Error:  25.37148100788636
# No. of estimators:  354
# Error:  25.29048151821745
# No. of estimators:  355
# Error:  25.26092081724624
# No. of estimators:  356
# Error:  25.221350787122027
# No. of estimators:  357
# Error:  25.23844201579441
# No. of estimators:  358
# Error:  25.229152332643594
# No. of estimators:  359
# Error:  25.22857303252901
# No. of estimators:  360
# Error:  25.21953929731062
# No. of estimators:  361
# Error:  25.153596860947466
# No. of estimators:  362
# Error:  25.151457185952257
# No. of estimators:  363
# Error:  25.13112889271726
# No. of estimators:  364
# Error:  25.098778342850487
# No. of estimators:  365
# Error:  25.036347146827538
# No. of estimators:  366
# Error:  25.02565830802545
# No. of estimators:  367
# Error:  25.002837284890354
# No. of estimators:  368
# Error:  25.00419688799821
# No. of estimators:  369
# Error:  24.95502777873624
# No. of estimators:  370
# Error:  24.93860616810703
# No. of estimators:  371
# Error:  24.92465574641186
# No. of estimators:  372
# Error:  24.922875092287065
# No. of estimators:  373
# Error:  24.892767285140692
# No. of estimators:  374
# Error:  24.890336580337955
# No. of estimators:  375
# Error:  24.8791843470947
# No. of estimators:  376
# Error:  24.797519810153464
# No. of estimators:  377
# Error:  24.806380908979794
# No. of estimators:  378
# Error:  24.79384570032322
# No. of estimators:  379
# Error:  24.789370185248433
# No. of estimators:  380
# Error:  24.78267245769711
# No. of estimators:  381
# Error:  24.784146303745853
# No. of estimators:  382
# Error:  24.782985570060898
# No. of estimators:  383
# Error:  24.7839047543693
# No. of estimators:  384
# Error:  24.78079878046839
# No. of estimators:  385
# Error:  24.76840719783124
# No. of estimators:  386
# Error:  24.765533137745795
# No. of estimators:  387
# Error:  24.754066776105823
# No. of estimators:  388
# Error:  24.730114547176836
# No. of estimators:  389
# Error:  24.696768859450064
# No. of estimators:  390
# Error:  24.66153052003942
# No. of estimators:  391
# Error:  24.650182613291083
# No. of estimators:  392
# Error:  24.63522249225052
# No. of estimators:  393
# Error:  24.656177379878137
# No. of estimators:  394
# Error:  24.6254346298109
# No. of estimators:  395
# Error:  24.617972302091346
# No. of estimators:  396
# Error:  24.595888280579203
# No. of estimators:  397
# Error:  24.603953316511838
# No. of estimators:  398
# Error:  24.60193072854717
# No. of estimators:  399
# Error:  24.605715494833056
# No. of estimators:  400
# Error:  24.600529849437947
# No. of estimators:  401
# Error:  24.54764286494336
# No. of estimators:  402
# Error:  24.54887480620673
# No. of estimators:  403
# Error:  24.53116072138639
# No. of estimators:  404
# Error:  24.522487162343975
# No. of estimators:  405
# Error:  24.45688986606582
# No. of estimators:  406
# Error:  24.431593439913396
# No. of estimators:  407
# Error:  24.425344914014197
# No. of estimators:  408
# Error:  24.394060489963813
# No. of estimators:  409
# Error:  24.397751210273025
# No. of estimators:  410
# Error:  24.32897156986486
# No. of estimators:  411
# Error:  24.307899001180303
# No. of estimators:  412
# Error:  24.275286518615
# No. of estimators:  413
# Error:  24.23190307929193
# No. of estimators:  414
# Error:  24.201999952659794
# No. of estimators:  415
# Error:  24.19833615113857
# No. of estimators:  416
# Error:  24.187398594017402
# No. of estimators:  417
# Error:  24.179021523873992
# No. of estimators:  418
# Error:  24.1134008203377
# No. of estimators:  419
# Error:  24.09684991625559
# No. of estimators:  420
# Error:  24.097573650889466
# No. of estimators:  421
# Error:  24.111334386198536
# No. of estimators:  422
# Error:  24.108337980680957
# No. of estimators:  423
# Error:  24.10385665369425
# No. of estimators:  424
# Error:  24.07656143661325
# No. of estimators:  425
# Error:  24.076966162502856
# No. of estimators:  426
# Error:  24.0292692730137
# No. of estimators:  427
# Error:  24.015036069101132
# No. of estimators:  428
# Error:  23.99779485071081
# No. of estimators:  429
# Error:  23.997538590258973
# No. of estimators:  430
# Error:  23.964587733086898
# No. of estimators:  431
# Error:  23.95180683896592
# No. of estimators:  432
# Error:  23.952230437851973
# No. of estimators:  433
# Error:  23.952460911061575
# No. of estimators:  434
# Error:  24.016019656388178
# No. of estimators:  435
# Error:  24.002381763624932
# No. of estimators:  436
# Error:  24.001253203581275
# No. of estimators:  437
# Error:  23.984447143736777
# No. of estimators:  438
# Error:  23.98555156112834
# No. of estimators:  439
# Error:  23.964611485361328
# No. of estimators:  440
# Error:  23.969346771521753
# No. of estimators:  441
# Error:  23.979344206113108

# %%
n_estimators # best num of estimators from early stopping
# Out:
# 441

# %%
# reshuffle train and test data
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2)

# %%
gbr_best = GradientBoostingRegressor(max_depth = 3, n_estimators = n_estimators)

gbr_best.fit(x_train, y_train)
# Out:
# GradientBoostingRegressor(n_estimators=441)

# %%
y_pred = gbr_best.predict(x_test)

r2_score(y_test, y_pred)
# Out:
# 0.9419418381848697
